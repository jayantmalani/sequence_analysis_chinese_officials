# %%
import pandas as pd

# %%
f = open('codebook_regions.txt',encoding = "utf8")
codelines = f.readlines()

# %%
codelines
# Out:
# ['Beijing 北京市 (2001-2010.99):\n',
#  '\n',
#  '2001=Provincial Party Secretary (省委书记);2001.1=Provincial Governor (省长); 2001.3=Provincial Discipline and Inspection Committee Secretary (省纪委书记);  2001.5=Provincial People’s Congress Chairman (省人大主席); 2001.7=Provincial Consultative Conference Chairman (省政协主席); 2001.9=Provincial Advisory Committee Chairman (省顾问委员会主席)\n',
#  '2003=Provincial Vice Secretary (省委副书记); 2003.1=Vice Provincial Governor (副省长); 2003.3= Provincial Standing Committee Member (省委常委);2003.4=Provincial Discipline and Inspection Committee Vice Secretary (省纪委副书记); 2003.5=Provincial People’s Congress Vice Chair (省人大副主席); 2003.7=PPCC Vice Chair (省政协副主席); 2003.9=Provincial Advisory Committee Vice Chairman (省顾问委员会副主席)\n',
#  '\n',
# ...

# %%
for line in codeline:
    if line

# %%
provinces = [[]]
temp = []

#for line in codelines:
#    print line
    
for line in codelines:
    if (line[0] == '+'):
        provinces.append(temp)
        temp = []
        temp.append(line)
        
    else:
        temp.append(line)

# %%
len(provinces)
# Out:
# 34
